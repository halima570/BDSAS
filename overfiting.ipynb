# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Synthetic dataset
age = np.array([20, 25, 30, 35, 40, 45, 50]).reshape(-1, 1)
income = np.array([30000, 35000, 40000, 45000, 50000, 55000, 60000])

# Plot the data
plt.scatter(age, income, color='blue', label='Data')

# Fit linear regression model
lin_reg = LinearRegression()
lin_reg.fit(age, income)
y_pred_lin = lin_reg.predict(age)
plt.plot(age, y_pred_lin, color='red', label='Linear Regression')

# Fit high-degree polynomial regression model
poly_features = PolynomialFeatures(degree=10)
X_poly = poly_features.fit_transform(age)
poly_reg = LinearRegression()
poly_reg.fit(X_poly, income)
y_pred_poly = poly_reg.predict(X_poly)
plt.plot(age, y_pred_poly, color='green', label='Polynomial Regression (degree 10)')

# Evaluate models
mse_lin = mean_squared_error(income, y_pred_lin)
mse_poly = mean_squared_error(income, y_pred_poly)
print(f"Mean Squared Error (Linear Regression): {mse_lin}")
print(f"Mean Squared Error (Polynomial Regression): {mse_poly}")

plt.xlabel('Age')
plt.ylabel('Income')
plt.title('Polynomial Regression Example')
plt.legend()
plt.show()
# Out:
# Mean Squared Error (Linear Regression): 9.453492714891745e-24
# Mean Squared Error (Polynomial Regression): 9.062000341374604e-11

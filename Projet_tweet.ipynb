# %% [markdown]
# # Scraping avec ntscraper

# %%
from ntscraper import Nitter
scraper = Nitter()
# Out:
# Testing instances:  92%|██████████████████████████████████████████████████████████     | 71/77 [01:07<00:05,  1.02it/s]
# 06-May-24 18:26:43 - Certificate did not match expected hostname: nt.ggtyler.dev. Certificate: {'subject': ((('commonName', '4g.ggtyler.dev'),),), 'issuer': ((('countryName', 'US'),), (('organizationName', "Let's Encrypt"),), (('commonName', 'R3'),)), 'version': 3, 'serialNumber': '048FA3D68DCD65927A6C57C2A3C9C1F8CA14', 'notBefore': 'Mar 15 00:26:35 2024 GMT', 'notAfter': 'Jun 13 00:26:34 2024 GMT', 'subjectAltName': (('DNS', '4g.ggtyler.dev'),), 'OCSP': ('http://r3.o.lencr.org',), 'caIssuers': ('http://r3.i.lencr.org/',)}
# Testing instances:  94%|██████████████████████████████████████████████████████████▉    | 72/77 [01:07<00:04,  1.15it/s]
# ...

# %%
import pandas as pd
def get_tweets(terme,mode,nombre):
    tweets = scraper.get_tweets(terme,mode=mode,number=nombre)
    final_tweets = []

    for tweet in tweets['tweets']:
        data_tweet = [tweet['link'], tweet['text'], tweet['date'], tweet['stats']['likes'], tweet['stats']['comments']]
        final_tweets.append(data_tweet)

    data_df = pd.DataFrame(final_tweets, columns=['link', 'text', 'date', 'Likes', 'Comments'])
    return data_df
# Out:
# 06-May-24 18:37:43 - NumExpr defaulting to 4 threads.

# %%
tweet = get_tweets("ChatGPT",'hashtag',100)
# Out:
# 06-May-24 18:37:48 - No instance specified, using random instance https://nitter.esmailelbob.xyz
# 06-May-24 18:37:54 - Current stats for ChatGPT: 18 tweets, 0 threads...
# 06-May-24 18:37:59 - Current stats for ChatGPT: 36 tweets, 0 threads...
# 06-May-24 18:38:01 - Fetching error: Instance has been rate limited.Use another instance or try again later.

# %%
tweet
# Out:
#                                                  link  \
# 0   https://twitter.com/tmrhyne/status/17875360372...
# 1   https://twitter.com/tosutekno/status/178753593...
# 2   https://twitter.com/MaimoUrology/status/178724...
# 3   https://twitter.com/goJedaAi/status/1787535508...
# 4   https://twitter.com/double_masters/status/1787...
# 5   https://twitter.com/LucSpighel/status/17875354...
# 6   https://twitter.com/bobehayes/status/178753530...
# 7   https://twitter.com/Pla2Freelancers/status/178...
# 8   https://twitter.com/ipfconline1/status/1787369...
# 9   https://twitter.com/kidehen/status/17875349482...
# 10  https://twitter.com/ino_0121/status/1787533956...
# 11  https://twitter.com/SkarredGhost/status/178749...
# 12  https://twitter.com/CoolWearables/status/17875...
# 13  https://twitter.com/gracepeacelove7/status/178...
# 14  https://twitter.com/giga_labs/status/178753354...
# 15  https://twitter.com/reisquarteu/status/1787533...
# ...

# %% [markdown]
# # Save au fichier CSV

# %%
tweet.to_csv('ChatGPT1.csv', index=False)

# %%
tweets = tweet.to_dict(orient='records')
tweets
# Out:
# [{'link': 'https://twitter.com/tmrhyne/status/1787536037289349303#m',
#   'text': "#ChatGPT ChatGPT's  Peach Fuzz Doverging #pantone #ieeevis #dataviz #infovis #colourlovers #colortheory #VisualAnalytics #DurhamCountyLib #colortheory #color #siggraph #AdobeColor #IEEECGA",
#   'date': 'May 6, 2024 · 5:32 PM UTC',
#   'Likes': 0,
#   'Comments': 0},
#  {'link': 'https://twitter.com/tosutekno/status/1787535930653646947#m',
#   'text': 'OpenAI Segera Luncurkan Mesin Pencari Berbasis ChatGPT  https://www.tosutekno.com/2024/05/openai-segera-luncurkan-mesin-pencari.html #ChatGPT #OpenAI',
#   'date': 'May 6, 2024 · 5:32 PM UTC',
#   'Likes': 0,
#   'Comments': 0},
#  {'link': 'https://twitter.com/MaimoUrology/status/1787245206712000630#m',
#   'text': 'Research year resident and PGY-3, Yitzchak Katlowitz, presenting on the success of ChatGPT 🤖 in the management of urologic trauma 🦾 @MaimoHealth @NYSAUA #urology #residency #researchyear #ChatGPT #technology #trauma',
# ...

# %% [markdown]
# # Stockage au MongoDB

# %%
from pymongo import MongoClient
cluster=MongoClient("mongodb+srv://halima:halima@cluster0.wjt9qvc.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db=cluster['tweet']
collection=db['ChatGPT']
collection.insert_one(tweets)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11676\2810223938.py in <module>
#       3 db=cluster['tweet']
#       4 collection=db['ChatGPT']
# ----> 5 collection.insert_one(tweets)
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session, comment)
#     661         .. versionadded:: 3.0
#     662         """
# --> 663         common.validate_is_document_type("document", document)
#     664         if not (isinstance(document, RawBSONDocument) or "_id" in document):
#     665             document["_id"] = ObjectId()  # type: ignore[index]
#
# ~\anaconda3\lib\site-packages\pymongo\common.py in validate_is_document_type(option, value)
#     550     """Validate the type of method arguments that expect a MongoDB document."""
# ...

# %% [markdown]
# # Classification

# %%
from textblob import TextBlob
import pandas as pd

df = pd.read_csv('ChatGPT1.csv')

# Function to get sentiment label
def get_sentiment_label(text):
    analysis = TextBlob(text)
    polarity = analysis.sentiment.polarity
    
    # Determine sentiment label based on polarity score
    if polarity > 0:
        return 'Positive'
    elif polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

# Apply sentiment analysis to each text in the DataFrame
df['sentiment'] = df['text'].apply(get_sentiment_label)

# %%
sentiments = df.sentiment

# %%
sentiments
# Out:
# 0      Neutral
# 1      Neutral
# 2     Positive
# 3      Neutral
# 4     Positive
# 5      Neutral
# 6      Neutral
# 7     Negative
# 8     Negative
# 9      Neutral
# 10     Neutral
# 11     Neutral
# 12     Neutral
# 13     Neutral
# 14     Neutral
# 15     Neutral
# 16     Neutral
# 17     Neutral
# 18     Neutral
# 19     Neutral
# 20    Negative
# 21    Positive
# 22     Neutral
# 23    Positive
# 24     Neutral
# 25     Neutral
# 26    Negative
# 27    Negative
# 28     Neutral
# 29    Positive
# 30     Neutral
# 31    Positive
# 32     Neutral
# 33     Neutral
# 34    Positive
# 35    Negative
# Name: sentiment, dtype: object

# %% [markdown]
# # Le resultat de classification sous format csv

# %%
resultats = df.to_csv("sentiment_ChatGPT.csv", index=False)

# %%
df
# Out:
#                                                  link  \
# 0   https://twitter.com/tmrhyne/status/17875360372...
# 1   https://twitter.com/tosutekno/status/178753593...
# 2   https://twitter.com/MaimoUrology/status/178724...
# 3   https://twitter.com/goJedaAi/status/1787535508...
# 4   https://twitter.com/double_masters/status/1787...
# 5   https://twitter.com/LucSpighel/status/17875354...
# 6   https://twitter.com/bobehayes/status/178753530...
# 7   https://twitter.com/Pla2Freelancers/status/178...
# 8   https://twitter.com/ipfconline1/status/1787369...
# 9   https://twitter.com/kidehen/status/17875349482...
# 10  https://twitter.com/ino_0121/status/1787533956...
# 11  https://twitter.com/SkarredGhost/status/178749...
# 12  https://twitter.com/CoolWearables/status/17875...
# 13  https://twitter.com/gracepeacelove7/status/178...
# 14  https://twitter.com/giga_labs/status/178753354...
# 15  https://twitter.com/reisquarteu/status/1787533...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Compter le nombre de chaque type de sentiment
sentiment_counts = df['sentiment'].value_counts()

# Créer un diagramme à barres (bar chart)
plt.figure(figsize=(8, 6))
sns.countplot(x='sentiment', data=df, palette='pastel')
plt.title('Répartition des sentiments')
plt.xlabel('Sentiment')
plt.ylabel('Nombre de tweets')
plt.show()

# %% [markdown]
# # Le fichier csv on va convertir sous format dictionaire pour le stochage dans Mongodb

# %%
# Convertir le DataFrame pandas en une liste de dictionnaires
sentiment_list = df.to_dict(orient='records')
sentiment_list
# Out:
# [{'link': 'https://twitter.com/tmrhyne/status/1787536037289349303#m',
#   'text': "#ChatGPT ChatGPT's  Peach Fuzz Doverging #pantone #ieeevis #dataviz #infovis #colourlovers #colortheory #VisualAnalytics #DurhamCountyLib #colortheory #color #siggraph #AdobeColor #IEEECGA",
#   'date': 'May 6, 2024 · 5:32 PM UTC',
#   'Likes': 0,
#   'Comments': 0,
#   'sentiment': 'Neutral'},
#  {'link': 'https://twitter.com/tosutekno/status/1787535930653646947#m',
#   'text': 'OpenAI Segera Luncurkan Mesin Pencari Berbasis ChatGPT  https://www.tosutekno.com/2024/05/openai-segera-luncurkan-mesin-pencari.html #ChatGPT #OpenAI',
#   'date': 'May 6, 2024 · 5:32 PM UTC',
#   'Likes': 0,
#   'Comments': 0,
#   'sentiment': 'Neutral'},
#  {'link': 'https://twitter.com/MaimoUrology/status/1787245206712000630#m',
# ...

# %%
from pymongo import MongoClient
cluster=MongoClient("mongodb+srv://halima:halima@cluster0.wjt9qvc.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db=cluster['tweet']
collection=db['NLP']
collection.insert_one(sentiment_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11676\3421303155.py in <module>
#       3 db=cluster['tweet']
#       4 collection=db['NLP']
# ----> 5 collection.insert_one(sentiment_list)
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session, comment)
#     661         .. versionadded:: 3.0
#     662         """
# --> 663         common.validate_is_document_type("document", document)
#     664         if not (isinstance(document, RawBSONDocument) or "_id" in document):
#     665             document["_id"] = ObjectId()  # type: ignore[index]
#
# ~\anaconda3\lib\site-packages\pymongo\common.py in validate_is_document_type(option, value)
#     550     """Validate the type of method arguments that expect a MongoDB document."""
# ...
